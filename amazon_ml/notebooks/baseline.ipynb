# %% [markdown]
# # Amazon ML - Baseline Entity Matching Notebook
#
# This notebook contains exploratory analysis, candidate pair generation (blocking), feature extraction, and baseline modeling.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../src')

import normalize
import blocking
import features
import evaluate
